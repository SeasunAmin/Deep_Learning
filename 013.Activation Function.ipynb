# %% [markdown]
# # Activation Function

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_moons

x, y = make_moons(100, noise=0.25,random_state=2,)

# %%
plt.scatter(x[:,0],x[:,1],c=y,)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(128,input_dim=2,activation='linear'))
model.add(Dense(128,activation='linear'))
model.add(Dense (1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history1 = model.fit(x,y,epochs=500,validation_split=.20,verbose=0)

# %% [markdown]
#  **for using linear activation function model in ploting a line in decistion boundary**

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x, y.astype('int'), clf=model, legend=2)

plt.show()
# Out:
# 3888/3888 [==============================] - 4s 1ms/step

# %% [markdown]
# # Changing the activation function

# %%
model_2 = Sequential()

model_2.add(Dense(128,input_dim=2,activation='relu'))
model_2.add(Dense(128,activation='relu'))
model_2.add(Dense (1,activation='sigmoid'))

model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history2 = model_2.fit(x,y,epochs=500,validation_split=.20,verbose=0)

# %%
plot_decision_regions(x, y.astype('int'), clf=model_2, legend=2)

plt.show()
# Out:
# 3888/3888 [==============================] - 6s 2ms/step
